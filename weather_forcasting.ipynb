# %% [markdown]
# <a href="https://colab.research.google.com/github/fatema373/NLP/blob/main/weather_forcasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM,Dense,SimpleRNN,GRU,BatchNormalization
import tensorflow as tf
import keras
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # 1- Dataset

# %%
# !wget 'https://zenodo.org/record/4770937/files/weather_prediction_dataset.csv'
# Out:
# --2023-05-12 06:49:37--  https://zenodo.org/record/4770937/files/weather_prediction_dataset.csv
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2773815 (2.6M) [text/plain]
# Saving to: ‘weather_prediction_dataset.csv’
#
# weather_prediction_ 100%[===================>]   2.64M   302KB/s    in 9.0s
#
# 2023-05-12 06:49:49 (302 KB/s) - ‘weather_prediction_dataset.csv’ saved [2773815/2773815]

# %% [markdown]
# ## Read Dataset

# %%
df= pd.read_csv('/content/weather_prediction_dataset.csv')
df
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                  8            0.89          1.0286
# 1     20000102      1                  8            0.87          1.0318
# 2     20000103      1                  5            0.81          1.0314
# 3     20000104      1                  7            0.79          1.0262
# 4     20000105      1                  5            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                  7            0.82          1.0084
# 3650  20091229     12                  7            0.92          1.0028
# 3651  20091230     12                  8            0.92          0.9979
# 3652  20091231     12                  7            0.93          0.9958
# 3653  20100101      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                       0.20                 0.03             0.0
# 1                       0.25                 0.00             0.0
# 2                       0.50                 0.00             3.7
# 3                       0.63                 0.35             6.9
# 4                       0.51                 0.07             3.7
# ...                      ...                  ...             ...
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
# 3653                    0.08                 0.56             0.0
#
#       BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0                 2.9             1.6  ...                -9.3
# 1                 3.6             2.7  ...                 0.5
# 2                 2.2             0.1  ...                -1.0
# 3                 3.9             0.5  ...                 2.5
# 4                 6.0             3.8  ...                -1.8
# ...               ...             ...  ...                 ...
# 3649              3.2             1.0  ...                -2.7
# 3650              4.5             2.4  ...                -9.5
# 3651              8.5             7.5  ...               -12.5
# 3652              6.6             4.3  ...                -9.3
# 3653              2.9            -0.2  ...                -8.8
#
#       STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 0                    0.7               1.6            0.97          1.0275
# 1                    2.0               2.0            0.99          1.0293
# 2                    2.8               3.4            0.91          1.0267
# 3                    4.6               4.9            0.95          1.0222
# 4                    2.9               3.6            0.95          1.0209
# ...                  ...               ...             ...             ...
# 3649                 2.4               3.7            0.95          1.0011
# 3650                 0.8               5.3            0.89          0.9966
# 3651                -7.4               3.8            0.88          0.9939
# 3652                -6.5               4.2            0.88          0.9933
# 3653                -7.0               3.4            0.86          1.0040
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 0                       0.25                 0.04              8.5
# 1                       0.17                 0.16              7.9
# 2                       0.27                 0.00              8.1
# 3                       0.11                 0.44              8.6
# 4                       0.39                 0.04              8.0
# ...                      ...                  ...              ...
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
# 3653                    0.11                 0.00              0.5
#
#       TOURS_temp_min  TOURS_temp_max
# 0                7.2             9.8
# 1                6.6             9.2
# 2                6.6             9.6
# 3                6.4            10.8
# 4                6.4             9.5
# ...              ...             ...
# 3649             1.8            10.6
# 3650             6.2            14.5
# 3651             8.7            11.3
# 3652             6.2            10.9
# 3653            -0.7             1.8
#
# [3654 rows x 165 columns]

# %%
def split_date(date_):
  year=date_[:4]
  month=date_[4:6]
  day=date_[6:]
  return f"{year}-{month}-{day}"

# %%
# to get year col for splitting data based on year in the later steps we convert date to be like yyyy-mm-dd
df['DATE']=df['DATE'].apply(lambda x:split_date(str(x)))

# %%
df
# Out:
#             DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     2000-01-01      1                  8            0.89          1.0286
# 1     2000-01-02      1                  8            0.87          1.0318
# 2     2000-01-03      1                  5            0.81          1.0314
# 3     2000-01-04      1                  7            0.79          1.0262
# 4     2000-01-05      1                  5            0.90          1.0246
# ...          ...    ...                ...             ...             ...
# 3649  2009-12-28     12                  7            0.82          1.0084
# 3650  2009-12-29     12                  7            0.92          1.0028
# 3651  2009-12-30     12                  8            0.92          0.9979
# 3652  2009-12-31     12                  7            0.93          0.9958
# 3653  2010-01-01      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                       0.20                 0.03             0.0
# 1                       0.25                 0.00             0.0
# 2                       0.50                 0.00             3.7
# 3                       0.63                 0.35             6.9
# 4                       0.51                 0.07             3.7
# ...                      ...                  ...             ...
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
# 3653                    0.08                 0.56             0.0
#
#       BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0                 2.9             1.6  ...                -9.3
# 1                 3.6             2.7  ...                 0.5
# 2                 2.2             0.1  ...                -1.0
# 3                 3.9             0.5  ...                 2.5
# 4                 6.0             3.8  ...                -1.8
# ...               ...             ...  ...                 ...
# 3649              3.2             1.0  ...                -2.7
# 3650              4.5             2.4  ...                -9.5
# 3651              8.5             7.5  ...               -12.5
# 3652              6.6             4.3  ...                -9.3
# 3653              2.9            -0.2  ...                -8.8
#
#       STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 0                    0.7               1.6            0.97          1.0275
# 1                    2.0               2.0            0.99          1.0293
# 2                    2.8               3.4            0.91          1.0267
# 3                    4.6               4.9            0.95          1.0222
# 4                    2.9               3.6            0.95          1.0209
# ...                  ...               ...             ...             ...
# 3649                 2.4               3.7            0.95          1.0011
# 3650                 0.8               5.3            0.89          0.9966
# 3651                -7.4               3.8            0.88          0.9939
# 3652                -6.5               4.2            0.88          0.9933
# 3653                -7.0               3.4            0.86          1.0040
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 0                       0.25                 0.04              8.5
# 1                       0.17                 0.16              7.9
# 2                       0.27                 0.00              8.1
# 3                       0.11                 0.44              8.6
# 4                       0.39                 0.04              8.0
# ...                      ...                  ...              ...
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
# 3653                    0.11                 0.00              0.5
#
#       TOURS_temp_min  TOURS_temp_max
# 0                7.2             9.8
# 1                6.6             9.2
# 2                6.6             9.6
# 3                6.4            10.8
# 4                6.4             9.5
# ...              ...             ...
# 3649             1.8            10.6
# 3650             6.2            14.5
# 3651             8.7            11.3
# 3652             6.2            10.9
# 3653            -0.7             1.8
#
# [3654 rows x 165 columns]

# %%
df['DATE']=pd.to_datetime(df['DATE'])
df['Year'] = df['DATE'].dt.year

# %% [markdown]
# ## Apply PCA for Feature Reduction

# %%
#get all features and drop unnecessery cols
X=df.drop(['TOURS_temp_max','Year','DATE'],axis=1)
X
# Out:
#       MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0         1                  8            0.89          1.0286
# 1         1                  8            0.87          1.0318
# 2         1                  5            0.81          1.0314
# 3         1                  7            0.79          1.0262
# 4         1                  5            0.90          1.0246
# ...     ...                ...             ...             ...
# 3649     12                  7            0.82          1.0084
# 3650     12                  7            0.92          1.0028
# 3651     12                  8            0.92          0.9979
# 3652     12                  7            0.93          0.9958
# 3653      1                  8            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                       0.20                 0.03             0.0
# 1                       0.25                 0.00             0.0
# 2                       0.50                 0.00             3.7
# 3                       0.63                 0.35             6.9
# 4                       0.51                 0.07             3.7
# ...                      ...                  ...             ...
# 3649                    0.28                 0.42             0.3
# 3650                    0.22                 1.68             0.2
# 3651                    0.07                 1.54             0.0
# 3652                    0.17                 0.57             0.1
# 3653                    0.08                 0.56             0.0
#
#       BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max  ...  \
# 0                 2.9             1.6             3.9  ...
# 1                 3.6             2.7             4.8  ...
# 2                 2.2             0.1             4.8  ...
# 3                 3.9             0.5             7.5  ...
# 4                 6.0             3.8             8.6  ...
# ...               ...             ...             ...  ...
# 3649              3.2             1.0             4.8  ...
# 3650              4.5             2.4            10.0  ...
# 3651              8.5             7.5            11.5  ...
# 3652              6.6             4.3             7.9  ...
# 3653              2.9            -0.2             4.8  ...
#
#       STOCKHOLM_temp_mean  STOCKHOLM_temp_min  STOCKHOLM_temp_max  \
# 0                    -2.3                -9.3                 0.7
# 1                     1.3                 0.5                 2.0
# 2                     0.8                -1.0                 2.8
# 3                     3.5                 2.5                 4.6
# 4                    -0.6                -1.8                 2.9
# ...                   ...                 ...                 ...
# 3649                  1.1                -2.7                 2.4
# 3650                 -8.0                -9.5                 0.8
# 3651                 -9.5               -12.5                -7.4
# 3652                 -7.6                -9.3                -6.5
# 3653                 -7.6                -8.8                -7.0
#
#       TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 0                  1.6            0.97          1.0275
# 1                  2.0            0.99          1.0293
# 2                  3.4            0.91          1.0267
# 3                  4.9            0.95          1.0222
# 4                  3.6            0.95          1.0209
# ...                ...             ...             ...
# 3649               3.7            0.95          1.0011
# 3650               5.3            0.89          0.9966
# 3651               3.8            0.88          0.9939
# 3652               4.2            0.88          0.9933
# 3653               3.4            0.86          1.0040
#
#       TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 0                       0.25                 0.04              8.5
# 1                       0.17                 0.16              7.9
# 2                       0.27                 0.00              8.1
# 3                       0.11                 0.44              8.6
# 4                       0.39                 0.04              8.0
# ...                      ...                  ...              ...
# 3649                    0.22                 1.50              6.2
# 3650                    0.24                 0.40             10.4
# 3651                    0.24                 1.00             10.0
# 3652                    0.58                 0.02              8.5
# 3653                    0.11                 0.00              0.5
#
#       TOURS_temp_min
# 0                7.2
# 1                6.6
# 2                6.6
# 3                6.4
# 4                6.4
# ...              ...
# 3649             1.8
# 3650             6.2
# 3651             8.7
# 3652             6.2
# 3653            -0.7
#
# [3654 rows x 163 columns]

# %%
#get the best number of pca componenects that hold much variation of the data
pca_ = PCA()
pca_.fit(X)
plt.grid(True)
plt.plot(np.cumsum(pca_.explained_variance_ratio_ * 100))
plt.xlabel('PCA components for dataset')
plt.ylabel('Variance')
# Out:
# Text(0, 0.5, 'Variance')

# %%
# apply PCA with 50 component that holds more that 96% variation of the data
pca_X = PCA(n_components=50)
X_pca=pca_X.fit_transform(X=X)
X_pca
# Out:
# array([[ 66.77342123,  -1.79175967,   3.45770444, ...,  -2.39577643,
#           1.38515651,  -1.60624211],
#        [ 57.03037348,  -0.48242753,   1.45524422, ...,   1.3771734 ,
#          -0.23094115,   0.92669801],
#        [ 51.36066075,  -7.78526547,   1.58695298, ...,   3.02240958,
#           0.26796975,   0.33237087],
#        ...,
#        [ 55.70747237, -13.18496211,  17.19857006, ...,  -0.44130254,
#          -3.65366451,  -0.25406302],
#        [ 62.98702838, -11.54132386,   9.84880933, ...,  -1.12848279,
#          -0.43459488,  -0.81750154],
#        [ 74.14393429,  -6.71064713,   2.15620652, ...,  -2.125751  ,
#          -1.42232915,  -1.36351233]])

# %% [markdown]
# ## Dataset splitting

# %%
#convert the pca features to dataframe and add (Year, TOURS_temp_max) cols to it,
# so we have our new data in X_df variable
X_df=pd.DataFrame(X_pca)
X_df['Year']=df['Year']
X_df['TOURS_temp_max']=df['TOURS_temp_max']

# %% [markdown]
# ```
# X_df is our new dataset that (PCA output)
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_train=X_df.loc[(X_df['Year']<=2007)]
df_train
# Out:
#               0         1          2          3          4          5  \
# 0     66.773421 -1.791760   3.457704  -4.769862 -10.042634 -12.891867
# 1     57.030373 -0.482428   1.455244 -10.030863  -9.124562  -9.465604
# 2     51.360661 -7.785265   1.586953 -14.539712  -8.898830  -3.918864
# 3     47.290651 -4.169076   7.389767 -20.005109  -5.278304  -2.563873
# 4     51.470725  4.958848   8.822066  -5.844868  -1.637902  -5.114916
# ...         ...       ...        ...        ...        ...        ...
# 2917  60.815354 -0.657352  -9.922620 -14.761007 -11.875622  -4.223855
# 2918  59.293031  1.315722  -5.732258 -23.225187 -11.800919  -4.074687
# 2919  59.880382  2.151522   0.772387 -27.019763  -9.400085   1.662727
# 2920  58.750465 -5.093588  -5.726017 -16.835349  -7.137829  -8.088948
# 2921  64.958066  0.513443 -10.921978  -4.708911  -8.608543  -8.474952
#
#               6          7          8         9  ...        42        43  \
# 0      6.289041   9.864113  -7.816788 -6.586971  ...  0.083403 -1.947575
# 1      3.599904   6.890710  -3.871920 -1.223798  ... -3.056890 -0.698035
# 2     -0.481013  -1.419834   3.128625  0.244656  ... -0.803440  1.042818
# 3     -1.583863   3.388227  10.369761  5.296306  ... -0.154748 -2.382816
# 4     -1.331651  -5.337218  -0.194580 -2.472049  ... -2.110405 -0.031615
# ...         ...        ...        ...       ...  ...       ...       ...
# 2917  -6.927953  -1.021256   4.782368 -0.897857  ... -1.033142  0.082017
# 2918  -5.467431  -7.103574   6.256218  1.020699  ...  0.046886 -0.059609
# 2919 -10.269578  -8.794580   9.598084  6.897346  ... -0.319607 -0.959159
# 2920   0.475180  -0.678328   1.449032  0.358662  ... -0.534946 -2.258101
# 2921   3.851642  10.299662  -4.055805  2.751618  ... -0.872733 -1.618662
#
#             44        45        46        47        48        49  Year  \
# 0     1.051896  2.267699  0.020822 -2.395776  1.385157 -1.606242  2000
# 1    -1.393419  1.635033  0.085661  1.377173 -0.230941  0.926698  2000
# 2     0.797823 -0.698182 -0.970886  3.022410  0.267970  0.332371  2000
# 3     0.395826  1.645789 -1.598719 -0.640167 -2.960994  0.561336  2000
# 4    -1.584737  1.080592 -2.017555 -2.798466  0.385677 -1.271342  2000
# ...        ...       ...       ...       ...       ...       ...   ...
# 2917  1.140650 -0.005697  0.382731  0.473141  1.217133 -0.742795  2007
# 2918  2.328722  1.252626  1.722481  1.495898 -0.392550  2.021359  2007
# 2919 -0.435300 -1.437425  0.523406  0.279897  0.956634 -0.908883  2007
# 2920  1.461003 -0.624846 -1.433732 -0.671165 -1.189863  0.912979  2007
# 2921  0.207835 -0.453045 -0.693874 -0.648087 -2.559747 -0.400844  2007
#
#       TOURS_temp_max
# 0                9.8
# 1                9.2
# 2                9.6
# 3               10.8
# 4                9.5
# ...              ...
# 2917             8.8
# 2918             6.8
# 2919             9.3
# 2920             4.5
# 2921             6.1
#
# [2922 rows x 52 columns]

# %%
df_valid=X_df.loc[(X_df['Year']>2007)& (X_df['Year']<=2009)]
df_valid
# Out:
#               0          1          2          3          4          5  \
# 2922  78.373027   4.833665  -9.238407  -8.590132  -7.549212  -1.758182
# 2923  81.428546   7.163417  -6.222454  -7.311926   4.657115   2.121954
# 2924  78.122433  -5.081272  -2.787617  -1.626022   1.388118  -2.620080
# 2925  70.610846  -5.351110   2.011145  -4.279966  -4.671060 -10.560224
# 2926  58.823458 -10.864099   8.105806  -4.323201  -4.286795 -17.909828
# ...         ...        ...        ...        ...        ...        ...
# 3648  68.215466  -8.585055   6.564309   2.670935  -1.888612  -3.580520
# 3649  67.194341  -2.123492   4.822774   2.595998  -0.589877   4.269149
# 3650  65.372106  -3.291849   9.438260  19.151028  -6.485364  -2.982349
# 3651  55.707472 -13.184962  17.198570  27.782159 -11.142894 -11.818855
# 3652  62.987028 -11.541324   9.848809  31.980751 -10.517276  -2.437692
#
#               6         7         8         9  ...        42        43  \
# 2922   2.442494  3.706452 -6.727686 -0.331447  ... -0.051548 -1.724446
# 2923  -7.788295 -4.835467 -3.278700 -0.878287  ...  1.362892 -1.037630
# 2924  -5.984365  0.225241  2.319924  0.361619  ...  1.248197  0.836153
# 2925  -4.989417 -2.948891  7.570662 -2.528067  ... -2.228610  0.261863
# 2926  -4.850852 -2.878568  6.013180  0.210372  ...  2.777622 -0.288983
# ...         ...       ...       ...       ...  ...       ...       ...
# 3648  -1.063522 -1.221912 -2.465142  0.904422  ...  1.140252 -0.605222
# 3649   3.884345 -1.783321 -2.166496  2.821568  ...  0.621417 -0.985052
# 3650   5.286826 -2.216517  7.275442 -0.583132  ...  0.436102  1.579373
# 3651  10.322150 -1.980075  5.231712  4.508835  ... -0.009558 -2.391623
# 3652   5.163382 -0.867241  5.057003  1.353139  ... -3.333656  0.456497
#
#             44        45        46        47        48        49  Year  \
# 2922 -0.699047  0.531358 -1.355075  0.285012 -0.621024  1.104563  2008
# 2923 -1.077583 -1.100430 -0.915501 -0.782416  2.341298 -0.526508  2008
# 2924  0.945556  0.195886  0.348954  0.048574 -0.367974 -0.483115  2008
# 2925  1.181871 -0.816310 -2.330420 -0.335779 -0.143666 -3.103568  2008
# 2926  0.965191  0.138145  2.015198  0.767883  2.452980  1.001576  2008
# ...        ...       ...       ...       ...       ...       ...   ...
# 3648 -0.177157 -0.690738  1.095438 -1.669189  0.490874 -2.127325  2009
# 3649  0.344947 -1.841954 -0.149527  1.333088  1.243222 -1.948109  2009
# 3650  1.912176  1.079897  1.308012 -1.559352 -0.911685  0.226712  2009
# 3651  1.286348  1.505698  0.063780 -0.441303 -3.653665 -0.254063  2009
# 3652  1.349101  2.403561  0.791938 -1.128483 -0.434595 -0.817502  2009
#
#       TOURS_temp_max
# 2922             4.5
# 2923             3.8
# 2924             7.1
# 2925            10.0
# 2926            10.9
# ...              ...
# 3648             9.7
# 3649            10.6
# 3650            14.5
# 3651            11.3
# 3652            10.9
#
# [731 rows x 52 columns]

# %%
df_test=X_df.loc[(X_df['Year']>2009)]
df_test
# Out:
#               0         1         2          3        4         5        6  \
# 3653  74.143934 -6.710647  2.156207  28.310164  2.41242  3.300929 -3.18938
#
#              7         8         9  ...        42        43        44  \
# 3653 -0.746041  2.527182  0.289093  ... -0.160662 -1.639116 -2.384585
#
#             45        46        47        48        49  Year  TOURS_temp_max
# 3653  0.967231  1.534027 -2.125751 -1.422329 -1.363512  2010             1.8
#
# [1 rows x 52 columns]

# %%
X_train=np.array(df_train.drop(['TOURS_temp_max','Year'],axis=1))
X_valid=np.array(df_valid.drop(['TOURS_temp_max','Year'],axis=1))
X_test=np.array(df_test.drop(['TOURS_temp_max','Year'],axis=1))

# %%
y_train=np.array(df_train['TOURS_temp_max'])
y_valid=np.array(df_valid['TOURS_temp_max'])
y_test=np.array(df_test['TOURS_temp_max'])

# %% [markdown]
# # Modeling Part

# %%
X_train.shape
# Out:
# (2922, 50)

# %%
class Modeling:
  def __init__(self,X_train,y_train,X_valid,y_valid, time_step):
    self.time_step=time_step
    self.X_train,self.y_train=self.create_batch(X_train,y_train,time_step)
    self.X_valid,self.y_valid=self.create_batch(X_valid,y_valid,time_step)

    self.LSTM_model=self.LSTM_(input_shape=(self.time_step,self.X_train.shape[2]),time_step=self.time_step)
    self.RNN_model=self.RNN(input_shape=(time_step,self.X_train.shape[2]),time_step=self.time_step)
    self.GRU_model=self.GRU(input_shape=(time_step,self.X_train.shape[2]),time_step=self.time_step)
  #this function create the seq we want our data to be with the shape of it to pass it to LSTM model
  def create_batch(self,X_,y_, n_steps):
    X, y = [],[]
    for i in range(len(X_)-n_steps-1):
      X.append(X_[i:i+n_steps])
      y.append(y_[i:i+n_steps])
    X=np.array(X)
    X=X.reshape(X.shape[0],X.shape[1],X.shape[2])
    return X, np.array(y)

  # Define the LSTM model
  def LSTM_(self,input_shape,time_step):
    LSTM_model = Sequential()
    LSTM_model.add(LSTM(self.time_step,activation="relu", input_shape=input_shape,return_sequences=True,dropout=0.3))
    LSTM_model.add(BatchNormalization())
    LSTM_model.add(Dense(1))
    optimizer = keras.optimizers.Adam(lr=0.01)
    LSTM_model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mse'])
    LSTM_model.summary()
    return LSTM_model
  # Define the RNN model
  def RNN(self,input_shape,time_step):
    RNN_model = Sequential()
    RNN_model.add(SimpleRNN(units=time_step,activation="relu", return_sequences=True, input_shape=input_shape))
    RNN_model.add(BatchNormalization())
    RNN_model.add(Dense(1))
    optimizer = keras.optimizers.Adam(lr=0.01)
    RNN_model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mse'])
    RNN_model.summary()
    return RNN_model
  # Define the GRU model
  def GRU(self,input_shape,time_step):
    GRU_model = Sequential()
    GRU_model.add(GRU(time_step,activation="relu", return_sequences=True, input_shape=input_shape))
    GRU_model.add(BatchNormalization())
    GRU_model.add(Dense(1))
    optimizer = keras.optimizers.Adam(lr=0.01)
    GRU_model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mse'])
    GRU_model.summary()
    return GRU_model
  def fit_models(self):
    #Applying early stop based on val loss
    early_stop_LSTM = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True)
    early_stop_RNN = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True)
    early_stop_GRU = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True)
    print("Training LSTM Model:")
    self.LSTM_model.fit(self.X_train,self.y_train,epochs=100,validation_data=(self.X_valid, self.y_valid),verbose=1,callbacks=early_stop_LSTM)
    print("LSTM model early stopping in epoch no: {}".format(early_stop_LSTM.stopped_epoch+1))

    print("Training RNN Model:")
    self.RNN_model.fit(self.X_train,self.y_train,epochs=100,validation_data=(self.X_valid, self.y_valid),verbose=1,callbacks=early_stop_RNN)
    print("RNN model early stopping in epoch no: {}".format(early_stop_RNN.stopped_epoch+1))
    print("Training GRU Model:")
    self.GRU_model.fit(self.X_train,self.y_train,epochs=100,validation_data=(self.X_valid, self.y_valid),verbose=1,callbacks=early_stop_GRU)
    print("GRU model early stopping in epoch no: {}".format(early_stop_GRU.stopped_epoch+1))

# %% [markdown]
# # Time step setting

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
modeling_3=Modeling(X_train,y_train,X_valid,y_valid,3)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 3, 3)              648
#
#  batch_normalization_3 (Batc  (None, 3, 3)             12
#  hNormalization)
#
#  dense_3 (Dense)             (None, 3, 1)              4
#
# =================================================================
# Total params: 664
# Trainable params: 658
# Non-trainable params: 6
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 3, 3)              162
#
#  batch_normalization_4 (Batc  (None, 3, 3)             12
#  hNormalization)
#
#  dense_4 (Dense)             (None, 3, 1)              4
#
# =================================================================
# Total params: 178
# Trainable params: 172
# Non-trainable params: 6
# _________________________________________________________________
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 3, 3)              495
#
#  batch_normalization_5 (Batc  (None, 3, 3)             12
#  hNormalization)
#
#  dense_5 (Dense)             (None, 3, 1)              4
#
# =================================================================
# Total params: 511
# Trainable params: 505
# Non-trainable params: 6
# _________________________________________________________________

# %%
modeling_3.fit_models()
# Out:
# Training LSTM Model:
# Epoch 1/100
# 92/92 [==============================] - 6s 14ms/step - loss: 229.9628 - mse: 229.9628 - val_loss: 121.9342 - val_mse: 121.9342
# Epoch 2/100
# 92/92 [==============================] - 1s 10ms/step - loss: 52.3997 - mse: 52.3997 - val_loss: 7.2363 - val_mse: 7.2363
# Epoch 3/100
# 92/92 [==============================] - 1s 10ms/step - loss: 15.5250 - mse: 15.5250 - val_loss: 7.6113 - val_mse: 7.6113
# Epoch 4/100
# 92/92 [==============================] - 1s 10ms/step - loss: 15.0205 - mse: 15.0205 - val_loss: 8.1658 - val_mse: 8.1658
# Epoch 5/100
# 92/92 [==============================] - 2s 20ms/step - loss: 14.6399 - mse: 14.6399 - val_loss: 7.2013 - val_mse: 7.2013
# Epoch 6/100
# 92/92 [==============================] - 1s 13ms/step - loss: 14.6840 - mse: 14.6840 - val_loss: 7.7978 - val_mse: 7.7978
# Epoch 7/100
# 92/92 [==============================] - 1s 9ms/step - loss: 14.8708 - mse: 14.8708 - val_loss: 7.4315 - val_mse: 7.4315
# Epoch 8/100
# 92/92 [==============================] - 1s 9ms/step - loss: 14.1921 - mse: 14.1921 - val_loss: 8.2680 - val_mse: 8.2680
# Epoch 9/100
# 92/92 [==============================] - 1s 10ms/step - loss: 14.1050 - mse: 14.1050 - val_loss: 7.5708 - val_mse: 7.5708
# Epoch 10/100
# 92/92 [==============================] - 2s 17ms/step - loss: 13.8742 - mse: 13.8742 - val_loss: 9.6001 - val_mse: 9.6001
# Epoch 11/100
# 92/92 [==============================] - 2s 23ms/step - loss: 14.3806 - mse: 14.3806 - val_loss: 8.2874 - val_mse: 8.2874
# Epoch 12/100
# 92/92 [==============================] - 2s 22ms/step - loss: 13.7241 - mse: 13.7241 - val_loss: 7.5699 - val_mse: 7.5699
# Epoch 13/100
# 92/92 [==============================] - 2s 25ms/step - loss: 14.8126 - mse: 14.8126 - val_loss: 7.4776 - val_mse: 7.4776
# Epoch 14/100
# 92/92 [==============================] - 3s 27ms/step - loss: 14.6477 - mse: 14.6477 - val_loss: 7.4547 - val_mse: 7.4547
# Epoch 15/100
# 92/92 [==============================] - ETA: 0s - loss: 14.7226 - mse: 14.7226Restoring model weights from the end of the best epoch: 5.
# 92/92 [==============================] - 2s 24ms/step - loss: 14.7226 - mse: 14.7226 - val_loss: 8.9953 - val_mse: 8.9953
# Epoch 15: early stopping
# LSTM model early stopping in epoch no: 15
# Training RNN Model:
# Epoch 1/100
# 92/92 [==============================] - 3s 9ms/step - loss: 256.8376 - mse: 256.8376 - val_loss: 126.8856 - val_mse: 126.8856
# Epoch 2/100
# 92/92 [==============================] - 1s 6ms/step - loss: 61.8786 - mse: 61.8786 - val_loss: 11.4025 - val_mse: 11.4025
# Epoch 3/100
# 92/92 [==============================] - 1s 6ms/step - loss: 6.6836 - mse: 6.6836 - val_loss: 3.4746 - val_mse: 3.4746
# Epoch 4/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.8006 - mse: 5.8006 - val_loss: 3.3348 - val_mse: 3.3348
# Epoch 5/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.6771 - mse: 5.6771 - val_loss: 3.3062 - val_mse: 3.3062
# Epoch 6/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.8389 - mse: 5.8389 - val_loss: 3.2833 - val_mse: 3.2833
# Epoch 7/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.8340 - mse: 5.8340 - val_loss: 3.2708 - val_mse: 3.2708
# Epoch 8/100
# 92/92 [==============================] - 1s 7ms/step - loss: 5.1961 - mse: 5.1961 - val_loss: 3.5426 - val_mse: 3.5426
# Epoch 9/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.6725 - mse: 5.6725 - val_loss: 3.2844 - val_mse: 3.2844
# Epoch 10/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.1377 - mse: 5.1377 - val_loss: 3.3731 - val_mse: 3.3731
# Epoch 11/100
# 92/92 [==============================] - 1s 8ms/step - loss: 5.5599 - mse: 5.5599 - val_loss: 3.2559 - val_mse: 3.2559
# Epoch 12/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.6575 - mse: 5.6575 - val_loss: 3.5331 - val_mse: 3.5331
# Epoch 13/100
# 92/92 [==============================] - 1s 7ms/step - loss: 5.0421 - mse: 5.0421 - val_loss: 3.3280 - val_mse: 3.3280
# Epoch 14/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.3028 - mse: 5.3028 - val_loss: 3.3497 - val_mse: 3.3497
# Epoch 15/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.3595 - mse: 5.3595 - val_loss: 3.3757 - val_mse: 3.3757
# Epoch 16/100
# 92/92 [==============================] - 1s 7ms/step - loss: 5.5647 - mse: 5.5647 - val_loss: 3.3265 - val_mse: 3.3265
# Epoch 17/100
# 92/92 [==============================] - 1s 7ms/step - loss: 5.8821 - mse: 5.8821 - val_loss: 3.3316 - val_mse: 3.3316
# Epoch 18/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.2045 - mse: 5.2045 - val_loss: 3.4123 - val_mse: 3.4123
# Epoch 19/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.5443 - mse: 5.5443 - val_loss: 3.2646 - val_mse: 3.2646
# Epoch 20/100
# 92/92 [==============================] - 1s 7ms/step - loss: 5.2589 - mse: 5.2589 - val_loss: 3.2268 - val_mse: 3.2268
# Epoch 21/100
# 92/92 [==============================] - 1s 7ms/step - loss: 4.8894 - mse: 4.8894 - val_loss: 3.3375 - val_mse: 3.3375
# Epoch 22/100
# 92/92 [==============================] - 1s 6ms/step - loss: 6.0689 - mse: 6.0689 - val_loss: 3.4017 - val_mse: 3.4017
# Epoch 23/100
# 92/92 [==============================] - 1s 6ms/step - loss: 6.1061 - mse: 6.1061 - val_loss: 3.4324 - val_mse: 3.4324
# Epoch 24/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.4607 - mse: 5.4607 - val_loss: 3.2577 - val_mse: 3.2577
# Epoch 25/100
# 92/92 [==============================] - 1s 6ms/step - loss: 5.1866 - mse: 5.1866 - val_loss: 3.4407 - val_mse: 3.4407
# Epoch 26/100
# 92/92 [==============================] - 1s 7ms/step - loss: 5.1997 - mse: 5.1997 - val_loss: 3.2934 - val_mse: 3.2934
# Epoch 27/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.6385 - mse: 5.6385 - val_loss: 3.2424 - val_mse: 3.2424
# Epoch 28/100
# 92/92 [==============================] - 2s 22ms/step - loss: 5.1538 - mse: 5.1538 - val_loss: 3.3251 - val_mse: 3.3251
# Epoch 29/100
# 92/92 [==============================] - 1s 9ms/step - loss: 5.0124 - mse: 5.0124 - val_loss: 3.4337 - val_mse: 3.4337
# Epoch 30/100
# 88/92 [===========================>..] - ETA: 0s - loss: 5.5376 - mse: 5.5376Restoring model weights from the end of the best epoch: 20.
# 92/92 [==============================] - 1s 11ms/step - loss: 5.5418 - mse: 5.5418 - val_loss: 3.7547 - val_mse: 3.7547
# Epoch 30: early stopping
# RNN model early stopping in epoch no: 30
# Training GRU Model:
# Epoch 1/100
# 92/92 [==============================] - 4s 21ms/step - loss: 247.8417 - mse: 247.8417 - val_loss: 157.3888 - val_mse: 157.3888
# Epoch 2/100
# 92/92 [==============================] - 1s 12ms/step - loss: 58.2933 - mse: 58.2933 - val_loss: 14.0567 - val_mse: 14.0567
# Epoch 3/100
# 92/92 [==============================] - 1s 12ms/step - loss: 6.6092 - mse: 6.6092 - val_loss: 4.2475 - val_mse: 4.2475
# Epoch 4/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.4568 - mse: 5.4568 - val_loss: 3.8836 - val_mse: 3.8836
# Epoch 5/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.3330 - mse: 5.3330 - val_loss: 3.7004 - val_mse: 3.7004
# Epoch 6/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.4157 - mse: 5.4157 - val_loss: 3.5810 - val_mse: 3.5810
# Epoch 7/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.6055 - mse: 5.6055 - val_loss: 3.5546 - val_mse: 3.5546
# Epoch 8/100
# 92/92 [==============================] - 1s 12ms/step - loss: 4.9923 - mse: 4.9923 - val_loss: 3.6325 - val_mse: 3.6325
# Epoch 9/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.2413 - mse: 5.2413 - val_loss: 3.5978 - val_mse: 3.5978
# Epoch 10/100
# 92/92 [==============================] - 1s 14ms/step - loss: 5.0587 - mse: 5.0587 - val_loss: 3.6719 - val_mse: 3.6719
# Epoch 11/100
# 92/92 [==============================] - 2s 27ms/step - loss: 4.8498 - mse: 4.8498 - val_loss: 3.6712 - val_mse: 3.6712
# Epoch 12/100
# 92/92 [==============================] - 2s 25ms/step - loss: 5.1048 - mse: 5.1048 - val_loss: 3.6444 - val_mse: 3.6444
# Epoch 13/100
# 92/92 [==============================] - 1s 11ms/step - loss: 5.3485 - mse: 5.3485 - val_loss: 3.7990 - val_mse: 3.7990
# Epoch 14/100
# 92/92 [==============================] - 1s 11ms/step - loss: 6.0003 - mse: 6.0003 - val_loss: 4.0093 - val_mse: 4.0093
# Epoch 15/100
# 92/92 [==============================] - 1s 11ms/step - loss: 6.0852 - mse: 6.0852 - val_loss: 3.8064 - val_mse: 3.8064
# Epoch 16/100
# 92/92 [==============================] - 1s 12ms/step - loss: 5.1144 - mse: 5.1144 - val_loss: 3.6349 - val_mse: 3.6349
# Epoch 17/100
# 89/92 [============================>.] - ETA: 0s - loss: 5.4833 - mse: 5.4833Restoring model weights from the end of the best epoch: 7.
# 92/92 [==============================] - 1s 11ms/step - loss: 5.5291 - mse: 5.5291 - val_loss: 3.6975 - val_mse: 3.6975
# Epoch 17: early stopping
# GRU model early stopping in epoch no: 17

# %%
modeling_13=Modeling(X_train,y_train,X_valid,y_valid,13)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 13, 13)            3328
#
#  batch_normalization_6 (Batc  (None, 13, 13)           52
#  hNormalization)
#
#  dense_6 (Dense)             (None, 13, 1)             14
#
# =================================================================
# Total params: 3,394
# Trainable params: 3,368
# Non-trainable params: 26
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 13, 13)            832
#
#  batch_normalization_7 (Batc  (None, 13, 13)           52
#  hNormalization)
#
#  dense_7 (Dense)             (None, 13, 1)             14
#
# =================================================================
# Total params: 898
# Trainable params: 872
# Non-trainable params: 26
# _________________________________________________________________
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 13, 13)            2535
#
#  batch_normalization_8 (Batc  (None, 13, 13)           52
#  hNormalization)
#
#  dense_8 (Dense)             (None, 13, 1)             14
#
# =================================================================
# Total params: 2,601
# Trainable params: 2,575
# Non-trainable params: 26
# _________________________________________________________________

# %%
modeling_13.fit_models()
# Out:
# Training LSTM Model:
# Epoch 1/100
# 91/91 [==============================] - 4s 27ms/step - loss: 155.9917 - mse: 155.9917 - val_loss: 7.6351 - val_mse: 7.6351
# Epoch 2/100
# 91/91 [==============================] - 4s 47ms/step - loss: 9.7739 - mse: 9.7739 - val_loss: 7.7476 - val_mse: 7.7476
# Epoch 3/100
# 91/91 [==============================] - 2s 26ms/step - loss: 9.1878 - mse: 9.1878 - val_loss: 8.2243 - val_mse: 8.2243
# Epoch 4/100
# 91/91 [==============================] - 2s 25ms/step - loss: 8.2179 - mse: 8.2179 - val_loss: 8.5573 - val_mse: 8.5573
# Epoch 5/100
# 91/91 [==============================] - 2s 25ms/step - loss: 8.4125 - mse: 8.4125 - val_loss: 8.4672 - val_mse: 8.4672
# Epoch 6/100
# 91/91 [==============================] - 2s 26ms/step - loss: 7.9344 - mse: 7.9344 - val_loss: 8.1944 - val_mse: 8.1944
# Epoch 7/100
# 91/91 [==============================] - 4s 40ms/step - loss: 8.1071 - mse: 8.1071 - val_loss: 9.3056 - val_mse: 9.3056
# Epoch 8/100
# 91/91 [==============================] - 2s 26ms/step - loss: 7.6716 - mse: 7.6716 - val_loss: 8.9665 - val_mse: 8.9665
# Epoch 9/100
# 91/91 [==============================] - 2s 24ms/step - loss: 8.4024 - mse: 8.4024 - val_loss: 9.0848 - val_mse: 9.0848
# Epoch 10/100
# 91/91 [==============================] - 2s 25ms/step - loss: 7.5183 - mse: 7.5183 - val_loss: 8.4622 - val_mse: 8.4622
# Epoch 11/100
# 91/91 [==============================] - 2s 26ms/step - loss: 7.2216 - mse: 7.2216 - val_loss: 7.5080 - val_mse: 7.5080
# Epoch 12/100
# 91/91 [==============================] - 4s 39ms/step - loss: 7.5718 - mse: 7.5718 - val_loss: 6.3750 - val_mse: 6.3750
# Epoch 13/100
# 91/91 [==============================] - 2s 24ms/step - loss: 7.6864 - mse: 7.6864 - val_loss: 7.0305 - val_mse: 7.0305
# Epoch 14/100
# 91/91 [==============================] - 2s 25ms/step - loss: 7.9206 - mse: 7.9206 - val_loss: 9.4815 - val_mse: 9.4815
# Epoch 15/100
# 91/91 [==============================] - 2s 24ms/step - loss: 7.3864 - mse: 7.3864 - val_loss: 7.3889 - val_mse: 7.3889
# Epoch 16/100
# 91/91 [==============================] - 2s 27ms/step - loss: 7.5135 - mse: 7.5135 - val_loss: 7.3316 - val_mse: 7.3316
# Epoch 17/100
# 91/91 [==============================] - 3s 38ms/step - loss: 7.9602 - mse: 7.9602 - val_loss: 7.2511 - val_mse: 7.2511
# Epoch 18/100
# 91/91 [==============================] - 2s 26ms/step - loss: 7.4909 - mse: 7.4909 - val_loss: 5.9000 - val_mse: 5.9000
# Epoch 19/100
# 91/91 [==============================] - 2s 25ms/step - loss: 7.6660 - mse: 7.6660 - val_loss: 7.5540 - val_mse: 7.5540
# Epoch 20/100
# 91/91 [==============================] - 2s 26ms/step - loss: 7.3691 - mse: 7.3691 - val_loss: 8.4100 - val_mse: 8.4100
# Epoch 21/100
# 91/91 [==============================] - 3s 31ms/step - loss: 7.4460 - mse: 7.4460 - val_loss: 7.9532 - val_mse: 7.9532
# Epoch 22/100
# 91/91 [==============================] - 3s 33ms/step - loss: 7.5790 - mse: 7.5790 - val_loss: 7.2633 - val_mse: 7.2633
# Epoch 23/100
# 91/91 [==============================] - 2s 26ms/step - loss: 7.8783 - mse: 7.8783 - val_loss: 7.2310 - val_mse: 7.2310
# Epoch 24/100
# 91/91 [==============================] - 2s 26ms/step - loss: 7.6484 - mse: 7.6484 - val_loss: 6.7199 - val_mse: 6.7199
# Epoch 25/100
# 91/91 [==============================] - 2s 25ms/step - loss: 7.7692 - mse: 7.7692 - val_loss: 8.0322 - val_mse: 8.0322
# Epoch 26/100
# 91/91 [==============================] - 3s 38ms/step - loss: 7.6553 - mse: 7.6553 - val_loss: 7.8349 - val_mse: 7.8349
# Epoch 27/100
# 91/91 [==============================] - 2s 27ms/step - loss: 7.2726 - mse: 7.2726 - val_loss: 7.3927 - val_mse: 7.3927
# Epoch 28/100
# 89/91 [============================>.] - ETA: 0s - loss: 7.8490 - mse: 7.8490Restoring model weights from the end of the best epoch: 18.
# 91/91 [==============================] - 2s 27ms/step - loss: 7.8329 - mse: 7.8329 - val_loss: 7.3169 - val_mse: 7.3169
# Epoch 28: early stopping
# LSTM model early stopping in epoch no: 28
# Training RNN Model:
# Epoch 1/100
# 91/91 [==============================] - 2s 15ms/step - loss: 172.7898 - mse: 172.7898 - val_loss: 18.8119 - val_mse: 18.8119
# Epoch 2/100
# 91/91 [==============================] - 1s 12ms/step - loss: 5.9983 - mse: 5.9983 - val_loss: 4.2096 - val_mse: 4.2096
# Epoch 3/100
# 91/91 [==============================] - 1s 12ms/step - loss: 4.6065 - mse: 4.6065 - val_loss: 3.5249 - val_mse: 3.5249
# Epoch 4/100
# 91/91 [==============================] - 1s 15ms/step - loss: 5.0537 - mse: 5.0537 - val_loss: 3.4883 - val_mse: 3.4883
# Epoch 5/100
# 91/91 [==============================] - 2s 23ms/step - loss: 4.4994 - mse: 4.4994 - val_loss: 3.5425 - val_mse: 3.5425
# Epoch 6/100
# 91/91 [==============================] - 1s 13ms/step - loss: 4.8653 - mse: 4.8653 - val_loss: 4.6544 - val_mse: 4.6544
# Epoch 7/100
# 91/91 [==============================] - 1s 12ms/step - loss: 4.8792 - mse: 4.8792 - val_loss: 4.0456 - val_mse: 4.0456
# Epoch 8/100
# 91/91 [==============================] - 1s 13ms/step - loss: 4.5060 - mse: 4.5060 - val_loss: 3.6815 - val_mse: 3.6815
# Epoch 9/100
# 91/91 [==============================] - 1s 12ms/step - loss: 4.2887 - mse: 4.2887 - val_loss: 3.8835 - val_mse: 3.8835
# Epoch 10/100
# 91/91 [==============================] - 1s 12ms/step - loss: 3.7506 - mse: 3.7506 - val_loss: 4.4838 - val_mse: 4.4838
# Epoch 11/100
# 91/91 [==============================] - 1s 12ms/step - loss: 4.6300 - mse: 4.6300 - val_loss: 4.8098 - val_mse: 4.8098
# Epoch 12/100
# 91/91 [==============================] - 1s 12ms/step - loss: 4.1294 - mse: 4.1294 - val_loss: 3.8854 - val_mse: 3.8854
# Epoch 13/100
# 91/91 [==============================] - 1s 12ms/step - loss: 4.2631 - mse: 4.2631 - val_loss: 4.1474 - val_mse: 4.1474
# Epoch 14/100
# 90/91 [============================>.] - ETA: 0s - loss: 3.4008 - mse: 3.4008Restoring model weights from the end of the best epoch: 4.
# 91/91 [==============================] - 1s 16ms/step - loss: 3.4285 - mse: 3.4285 - val_loss: 4.1087 - val_mse: 4.1087
# Epoch 14: early stopping
# RNN model early stopping in epoch no: 14
# Training GRU Model:
# Epoch 1/100
# 91/91 [==============================] - 5s 32ms/step - loss: 155.2726 - mse: 155.2726 - val_loss: 11.3645 - val_mse: 11.3645
# Epoch 2/100
# 91/91 [==============================] - 3s 29ms/step - loss: 4.8751 - mse: 4.8751 - val_loss: 4.4445 - val_mse: 4.4445
# Epoch 3/100
# 91/91 [==============================] - 3s 30ms/step - loss: 4.4996 - mse: 4.4996 - val_loss: 3.7378 - val_mse: 3.7378
# Epoch 4/100
# 91/91 [==============================] - 4s 46ms/step - loss: 4.2085 - mse: 4.2085 - val_loss: 3.7452 - val_mse: 3.7452
# Epoch 5/100
# 91/91 [==============================] - 3s 30ms/step - loss: 4.2693 - mse: 4.2693 - val_loss: 3.7327 - val_mse: 3.7327
# Epoch 6/100
# 91/91 [==============================] - 3s 29ms/step - loss: 3.4970 - mse: 3.4970 - val_loss: 3.9097 - val_mse: 3.9097
# Epoch 7/100
# 91/91 [==============================] - 4s 43ms/step - loss: 3.1158 - mse: 3.1158 - val_loss: 4.4245 - val_mse: 4.4245
# Epoch 8/100
# 91/91 [==============================] - 4s 44ms/step - loss: 3.6933 - mse: 3.6933 - val_loss: 4.1712 - val_mse: 4.1712
# Epoch 9/100
# 91/91 [==============================] - 3s 29ms/step - loss: 3.6441 - mse: 3.6441 - val_loss: 4.2975 - val_mse: 4.2975
# Epoch 10/100
# 91/91 [==============================] - 3s 29ms/step - loss: 3.4637 - mse: 3.4637 - val_loss: 4.8391 - val_mse: 4.8391
# Epoch 11/100
# 91/91 [==============================] - 3s 30ms/step - loss: 4.0050 - mse: 4.0050 - val_loss: 4.3662 - val_mse: 4.3662
# Epoch 12/100
# 91/91 [==============================] - 4s 43ms/step - loss: 3.4883 - mse: 3.4883 - val_loss: 4.5142 - val_mse: 4.5142
# Epoch 13/100
# 91/91 [==============================] - 3s 29ms/step - loss: 3.2267 - mse: 3.2267 - val_loss: 4.6121 - val_mse: 4.6121
# Epoch 14/100
# 91/91 [==============================] - 3s 30ms/step - loss: 3.5101 - mse: 3.5101 - val_loss: 4.6881 - val_mse: 4.6881
# Epoch 15/100
# 91/91 [==============================] - ETA: 0s - loss: 3.3316 - mse: 3.3316Restoring model weights from the end of the best epoch: 5.
# 91/91 [==============================] - 3s 30ms/step - loss: 3.3316 - mse: 3.3316 - val_loss: 4.6126 - val_mse: 4.6126
# Epoch 15: early stopping
# GRU model early stopping in epoch no: 15

# %%
modeling_40=Modeling(X_train,y_train,X_valid,y_valid,40)
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 40, 40)            14560
#
#  batch_normalization_9 (Batc  (None, 40, 40)           160
#  hNormalization)
#
#  dense_9 (Dense)             (None, 40, 1)             41
#
# =================================================================
# Total params: 14,761
# Trainable params: 14,681
# Non-trainable params: 80
# _________________________________________________________________
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 40, 40)            3640
#
#  batch_normalization_10 (Bat  (None, 40, 40)           160
#  chNormalization)
#
#  dense_10 (Dense)            (None, 40, 1)             41
#
# =================================================================
# Total params: 3,841
# Trainable params: 3,761
# Non-trainable params: 80
# _________________________________________________________________
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 40, 40)            11040
#
#  batch_normalization_11 (Bat  (None, 40, 40)           160
#  chNormalization)
#
#  dense_11 (Dense)            (None, 40, 1)             41
#
# =================================================================
# Total params: 11,241
# Trainable params: 11,161
# Non-trainable params: 80
# _________________________________________________________________

# %%
modeling_40.fit_models()
# Out:
# Training LSTM Model:
# Epoch 1/100
# 89/89 [==============================] - 9s 77ms/step - loss: 129.6749 - mse: 129.6749 - val_loss: 55.9848 - val_mse: 55.9848
# Epoch 2/100
# 89/89 [==============================] - 7s 81ms/step - loss: 32.0204 - mse: 32.0204 - val_loss: 24.5942 - val_mse: 24.5942
# Epoch 3/100
# 89/89 [==============================] - 6s 67ms/step - loss: 35.8134 - mse: 35.8134 - val_loss: 78.2389 - val_mse: 78.2389
# Epoch 4/100
# 89/89 [==============================] - 7s 84ms/step - loss: 30.2003 - mse: 30.2003 - val_loss: 54.1885 - val_mse: 54.1885
# Epoch 5/100
# 89/89 [==============================] - 6s 67ms/step - loss: 26.1517 - mse: 26.1517 - val_loss: 54.7775 - val_mse: 54.7775
# Epoch 6/100
# 89/89 [==============================] - 7s 82ms/step - loss: 24.8768 - mse: 24.8768 - val_loss: 59.7167 - val_mse: 59.7167
# Epoch 7/100
# 89/89 [==============================] - 6s 67ms/step - loss: 24.5891 - mse: 24.5891 - val_loss: 58.6236 - val_mse: 58.6236
# Epoch 8/100
# 89/89 [==============================] - 7s 82ms/step - loss: 23.6288 - mse: 23.6288 - val_loss: 53.1144 - val_mse: 53.1144
# Epoch 9/100
# 89/89 [==============================] - 6s 69ms/step - loss: 24.1299 - mse: 24.1299 - val_loss: 51.5515 - val_mse: 51.5515
# Epoch 10/100
# 89/89 [==============================] - 7s 82ms/step - loss: 24.9071 - mse: 24.9071 - val_loss: 3957507.2500 - val_mse: 3957507.2500
# Epoch 11/100
# 89/89 [==============================] - 6s 68ms/step - loss: 24.2198 - mse: 24.2198 - val_loss: 53.4730 - val_mse: 53.4730
# Epoch 12/100
# 89/89 [==============================] - ETA: 0s - loss: 23.8383 - mse: 23.8383Restoring model weights from the end of the best epoch: 2.
# 89/89 [==============================] - 7s 77ms/step - loss: 23.8383 - mse: 23.8383 - val_loss: 53.5048 - val_mse: 53.5048
# Epoch 12: early stopping
# LSTM model early stopping in epoch no: 12
# Training RNN Model:
# Epoch 1/100
# 89/89 [==============================] - 4s 33ms/step - loss: 102.8374 - mse: 102.8374 - val_loss: 5.9419 - val_mse: 5.9419
# Epoch 2/100
# 89/89 [==============================] - 4s 44ms/step - loss: 3.7658 - mse: 3.7658 - val_loss: 4.4939 - val_mse: 4.4939
# Epoch 3/100
# 89/89 [==============================] - 3s 30ms/step - loss: 3.3960 - mse: 3.3960 - val_loss: 5.0135 - val_mse: 5.0135
# Epoch 4/100
# 89/89 [==============================] - 3s 30ms/step - loss: 2.9455 - mse: 2.9455 - val_loss: 4.9385 - val_mse: 4.9385
# Epoch 5/100
# 89/89 [==============================] - 3s 30ms/step - loss: 2.8174 - mse: 2.8174 - val_loss: 5.9145 - val_mse: 5.9145
# Epoch 6/100
# 89/89 [==============================] - 4s 42ms/step - loss: 3.1262 - mse: 3.1262 - val_loss: 5.3533 - val_mse: 5.3533
# Epoch 7/100
# 89/89 [==============================] - 3s 31ms/step - loss: 2.2990 - mse: 2.2990 - val_loss: 5.6245 - val_mse: 5.6245
# Epoch 8/100
# 89/89 [==============================] - 3s 29ms/step - loss: 2.8478 - mse: 2.8478 - val_loss: 5.8244 - val_mse: 5.8244
# Epoch 9/100
# 89/89 [==============================] - 3s 30ms/step - loss: 2.4588 - mse: 2.4588 - val_loss: 6.0644 - val_mse: 6.0644
# Epoch 10/100
# 89/89 [==============================] - 3s 34ms/step - loss: 2.7631 - mse: 2.7631 - val_loss: 5.9821 - val_mse: 5.9821
# Epoch 11/100
# 89/89 [==============================] - 4s 40ms/step - loss: 2.6658 - mse: 2.6658 - val_loss: 5.8789 - val_mse: 5.8789
# Epoch 12/100
# 88/89 [============================>.] - ETA: 0s - loss: 2.3992 - mse: 2.3992Restoring model weights from the end of the best epoch: 2.
# 89/89 [==============================] - 3s 30ms/step - loss: 2.3956 - mse: 2.3956 - val_loss: 7.2073 - val_mse: 7.2073
# Epoch 12: early stopping
# RNN model early stopping in epoch no: 12
# Training GRU Model:
# Epoch 1/100
# 89/89 [==============================] - 10s 96ms/step - loss: 94.8325 - mse: 94.8325 - val_loss: 6.8867 - val_mse: 6.8867
# Epoch 2/100
# 89/89 [==============================] - 7s 78ms/step - loss: 3.5879 - mse: 3.5879 - val_loss: 5.1586 - val_mse: 5.1586
# Epoch 3/100
# 89/89 [==============================] - 8s 93ms/step - loss: 3.0283 - mse: 3.0283 - val_loss: 5.0139 - val_mse: 5.0139
# Epoch 4/100
# 89/89 [==============================] - 8s 94ms/step - loss: 2.3372 - mse: 2.3372 - val_loss: 5.3844 - val_mse: 5.3844
# Epoch 5/100
# 89/89 [==============================] - 7s 78ms/step - loss: 2.6097 - mse: 2.6097 - val_loss: 5.9605 - val_mse: 5.9605
# Epoch 6/100
# 89/89 [==============================] - 8s 93ms/step - loss: 1.8532 - mse: 1.8532 - val_loss: 6.4097 - val_mse: 6.4097
# Epoch 7/100
# 89/89 [==============================] - 8s 85ms/step - loss: 1.7804 - mse: 1.7804 - val_loss: 6.4678 - val_mse: 6.4678
# Epoch 8/100
# 89/89 [==============================] - 8s 85ms/step - loss: 1.9557 - mse: 1.9557 - val_loss: 6.4163 - val_mse: 6.4163
# Epoch 9/100
# 89/89 [==============================] - 8s 93ms/step - loss: 1.5639 - mse: 1.5639 - val_loss: 6.2784 - val_mse: 6.2784
# Epoch 10/100
# 89/89 [==============================] - 7s 77ms/step - loss: 2.1746 - mse: 2.1746 - val_loss: 6.0486 - val_mse: 6.0486
# Epoch 11/100
# 89/89 [==============================] - 9s 96ms/step - loss: 1.7065 - mse: 1.7065 - val_loss: 6.1556 - val_mse: 6.1556
# Epoch 12/100
# 89/89 [==============================] - 8s 95ms/step - loss: 1.8791 - mse: 1.8791 - val_loss: 5.7520 - val_mse: 5.7520
# Epoch 13/100
# 89/89 [==============================] - ETA: 0s - loss: 2.1103 - mse: 2.1103Restoring model weights from the end of the best epoch: 3.
# 89/89 [==============================] - 7s 78ms/step - loss: 2.1103 - mse: 2.1103 - val_loss: 6.1742 - val_mse: 6.1742
# Epoch 13: early stopping
# GRU model early stopping in epoch no: 13

# %% [markdown]
# # `Conclusion`

# %% [markdown]
# ![image.png](data:image/png;base64,...)
